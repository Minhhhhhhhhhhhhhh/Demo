# %% [markdown]
# ## Kiểu dữ liệu

# %%
print('ive nothing to do with it') #Kiểu str (chuỗi)
# Out:
# ive nothing to do with it

# %%
print(101) #Kiểu int (số)

# %%
print(10.05) #Kiểu float (Thập phân)

# %%
print(True) #Boolen - bool
print(False) #Boolen - bool

# %% [markdown]
# # Toán tử

# %%
a = 10
b = 5
c = 2.5
d = 'Python'
e = 'Fundamental'

# %% [markdown]
# ## Toán tử cộng

# %%
print(a+b)
print(a+c)
# Out:
# 15
# 12.5

# %%
print(d+e)
# Out:
# PythonFundamental

# %%
print(a+True) #True = 1
print(a+False) #False = 0

# %% [markdown]
# ## Toán tử trừ

# %%
print(a-b)
# Out:
# 5

# %% [markdown]
# ## Toán tử nhân

# %%
print(b*c)
# Out:
# 12.5

# %%
print(b*d)
# Out:
# PythonPythonPythonPythonPython

# %% [markdown]
# ## Toán tử chia

# %%
print(a/b) #Kết quả phép tính chia luôn là float

# %% [markdown]
# ## Chia lấy dư

# %%
print(b % 2)
print(b // 2)
# Out:
# 1
# 2

# %% [markdown]
# ## Lũy thừa

# %%
print(2**3)
# Out:
# 8

# %% [markdown]
# ## Toán tử quan hệ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:bb7e4f6b-2001-44c0-b30e-086b503db7b0.png)

# %% [markdown]
# ## Phép gán

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Toán tử logic

# %% [markdown]
# ![image.png](attachment:image.png)
